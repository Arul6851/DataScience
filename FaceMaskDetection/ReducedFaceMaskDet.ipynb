# %%
# !python -m pip install --upgrade pip

# !pip install numpy
# !pip install scikit-learn
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn
# !pip install opencv-python
# !pip install tensorflow
# !pip install Pillow
# !pip install xml-python
# !pip install glob2
# Out:
# Requirement already satisfied: pip in d:\softwares\python\lib\site-packages (23.1.2)
# WARNING: Ignoring invalid distribution -upyter-core (d:\softwares\python\lib\site-packages)
# WARNING: Ignoring invalid distribution -upyter-core (d:\softwares\python\lib\site-packages)
# Requirement already satisfied: numpy in d:\softwares\python\lib\site-packages (1.23.4)
# WARNING: Ignoring invalid distribution -upyter-core (d:\softwares\python\lib\site-packages)
# WARNING: Ignoring invalid distribution -upyter-core (d:\softwares\python\lib\site-packages)
# Requirement already satisfied: scikit-learn in d:\softwares\python\lib\site-packages (1.1.3)
# Requirement already satisfied: numpy>=1.17.3 in d:\softwares\python\lib\site-packages (from scikit-learn) (1.23.4)
# Requirement already satisfied: scipy>=1.3.2 in d:\softwares\python\lib\site-packages (from scikit-learn) (1.9.3)
# Requirement already satisfied: joblib>=1.0.0 in d:\softwares\python\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\softwares\python\lib\site-packages (from scikit-learn) (3.1.0)
# WARNING: Ignoring invalid distribution -upyter-core (d:\softwares\python\lib\site-packages)
# WARNING: Ignoring invalid distribution -upyter-core (d:\softwares\python\lib\site-packages)
# Requirement already satisfied: pandas in d:\softwares\python\lib\site-packages (1.5.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in d:\softwares\python\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\softwares\python\lib\site-packages (from pandas) (2022.6)
# Requirement already satisfied: numpy>=1.21.0 in d:\softwares\python\lib\site-packages (from pandas) (1.23.4)
# Requirement already satisfied: six>=1.5 in d:\softwares\python\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# WARNING: Ignoring invalid distribution -upyter-core (d:\softwares\python\lib\site-packages)
# WARNING: Ignoring invalid distribution -upyter-core (d:\softwares\python\lib\site-packages)
# Requirement already satisfied: matplotlib in d:\softwares\python\lib\site-packages (3.6.2)
# Requirement already satisfied: contourpy>=1.0.1 in d:\softwares\python\lib\site-packages (from matplotlib) (1.0.6)
# Requirement already satisfied: cycler>=0.10 in d:\softwares\python\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\softwares\python\lib\site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\softwares\python\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.19 in d:\softwares\python\lib\site-packages (from matplotlib) (1.23.4)
# Requirement already satisfied: packaging>=20.0 in d:\softwares\python\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in d:\softwares\python\lib\site-packages (from matplotlib) (9.3.0)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\softwares\python\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in d:\softwares\python\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in d:\softwares\python\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# WARNING: Ignoring invalid distribution -upyter-core (d:\softwares\python\lib\site-packages)
# WARNING: Ignoring invalid distribution -upyter-core (d:\softwares\python\lib\site-packages)
# Requirement already satisfied: seaborn in d:\softwares\python\lib\site-packages (0.12.1)
# Requirement already satisfied: numpy>=1.17 in d:\softwares\python\lib\site-packages (from seaborn) (1.23.4)
# Requirement already satisfied: pandas>=0.25 in d:\softwares\python\lib\site-packages (from seaborn) (1.5.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in d:\softwares\python\lib\site-packages (from seaborn) (3.6.2)
# Requirement already satisfied: contourpy>=1.0.1 in d:\softwares\python\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.6)
# Requirement already satisfied: cycler>=0.10 in d:\softwares\python\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\softwares\python\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\softwares\python\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in d:\softwares\python\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in d:\softwares\python\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.3.0)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\softwares\python\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in d:\softwares\python\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\softwares\python\lib\site-packages (from pandas>=0.25->seaborn) (2022.6)
# Requirement already satisfied: six>=1.5 in d:\softwares\python\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# WARNING: Ignoring invalid distribution -upyter-core (d:\softwares\python\lib\site-packages)
# WARNING: Ignoring invalid distribution -upyter-core (d:\softwares\python\lib\site-packages)
# Requirement already satisfied: opencv-python in d:\softwares\python\lib\site-packages (4.7.0.72)
# Requirement already satisfied: numpy>=1.21.2 in d:\softwares\python\lib\site-packages (from opencv-python) (1.23.4)
# WARNING: Ignoring invalid distribution -upyter-core (d:\softwares\python\lib\site-packages)
# WARNING: Ignoring invalid distribution -upyter-core (d:\softwares\python\lib\site-packages)
# Requirement already satisfied: tensorflow in d:\softwares\python\lib\site-packages (2.12.0)
# Requirement already satisfied: tensorflow-intel==2.12.0 in d:\softwares\python\lib\site-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in d:\softwares\python\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in d:\softwares\python\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in d:\softwares\python\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (23.3.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in d:\softwares\python\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in d:\softwares\python\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in d:\softwares\python\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.8.0)
# Requirement already satisfied: jax>=0.3.15 in d:\softwares\python\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.4.8)
# Requirement already satisfied: libclang>=13.0.0 in d:\softwares\python\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (16.0.0)
# Requirement already satisfied: numpy<1.24,>=1.22 in d:\softwares\python\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.23.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in d:\softwares\python\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in d:\softwares\python\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (21.3)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in d:\softwares\python\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.23.0)
# Requirement already satisfied: setuptools in d:\softwares\python\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in d:\softwares\python\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in d:\softwares\python\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in d:\softwares\python\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in d:\softwares\python\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in d:\softwares\python\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.54.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in d:\softwares\python\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in d:\softwares\python\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Requirement already satisfied: keras<2.13,>=2.12.0 in d:\softwares\python\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in d:\softwares\python\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.31.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in d:\softwares\python\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.12.0->tensorflow) (0.40.0)
# Requirement already satisfied: ml-dtypes>=0.0.3 in d:\softwares\python\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: scipy>=1.7 in d:\softwares\python\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (1.9.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in d:\softwares\python\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in d:\softwares\python\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in d:\softwares\python\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in d:\softwares\python\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.28.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in d:\softwares\python\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.7.0)
# Requirement already satisfied: werkzeug>=1.0.1 in d:\softwares\python\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.3.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in d:\softwares\python\lib\site-packages (from packaging->tensorflow-intel==2.12.0->tensorflow) (3.0.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in d:\softwares\python\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\softwares\python\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\softwares\python\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in d:\softwares\python\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in d:\softwares\python\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in d:\softwares\python\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\softwares\python\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in d:\softwares\python\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2022.9.24)
# Requirement already satisfied: MarkupSafe>=2.1.1 in d:\softwares\python\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in d:\softwares\python\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in d:\softwares\python\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.2.2)
# WARNING: Ignoring invalid distribution -upyter-core (d:\softwares\python\lib\site-packages)
# WARNING: Ignoring invalid distribution -upyter-core (d:\softwares\python\lib\site-packages)
# Requirement already satisfied: Pillow in d:\softwares\python\lib\site-packages (9.3.0)
# WARNING: Ignoring invalid distribution -upyter-core (d:\softwares\python\lib\site-packages)
# WARNING: Ignoring invalid distribution -upyter-core (d:\softwares\python\lib\site-packages)
# Requirement already satisfied: xml-python in d:\softwares\python\lib\site-packages (0.4.3)
# Requirement already satisfied: attrs in d:\softwares\python\lib\site-packages (from xml-python) (22.1.0)
# WARNING: Ignoring invalid distribution -upyter-core (d:\softwares\python\lib\site-packages)
# WARNING: Ignoring invalid distribution -upyter-core (d:\softwares\python\lib\site-packages)
# Requirement already satisfied: glob2 in d:\softwares\python\lib\site-packages (0.7)
# WARNING: Ignoring invalid distribution -upyter-core (d:\softwares\python\lib\site-packages)
# WARNING: Ignoring invalid distribution -upyter-core (d:\softwares\python\lib\site-packages)

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle\\python Docker image: https:\\\\github.com\\kaggle\\docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I\\O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
import cv2
import seaborn as sns
import PIL
import xml.etree.ElementTree as ET
import glob

# Input data files are available in the read-only "..\\input\\" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('D:\\DataScience\\FaceMaskDetection\\reducedInput'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (\\kaggle\\working\\) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to \\kaggle\\temp\\, but they won't be saved outside of the current session
# Out:
# D:\DataScience\FaceMaskDetection\reducedInput\annotations\maksssksksss0.xml
# D:\DataScience\FaceMaskDetection\reducedInput\annotations\maksssksksss1.xml
# D:\DataScience\FaceMaskDetection\reducedInput\annotations\maksssksksss10.xml
# D:\DataScience\FaceMaskDetection\reducedInput\annotations\maksssksksss2.xml
# D:\DataScience\FaceMaskDetection\reducedInput\annotations\maksssksksss3.xml
# D:\DataScience\FaceMaskDetection\reducedInput\annotations\maksssksksss4.xml
# D:\DataScience\FaceMaskDetection\reducedInput\annotations\maksssksksss5.xml
# D:\DataScience\FaceMaskDetection\reducedInput\annotations\maksssksksss6.xml
# D:\DataScience\FaceMaskDetection\reducedInput\annotations\maksssksksss7.xml
# D:\DataScience\FaceMaskDetection\reducedInput\annotations\maksssksksss8.xml
# D:\DataScience\FaceMaskDetection\reducedInput\annotations\maksssksksss9.xml
# D:\DataScience\FaceMaskDetection\reducedInput\images\maksssksksss0.png
# D:\DataScience\FaceMaskDetection\reducedInput\images\maksssksksss1.png
# D:\DataScience\FaceMaskDetection\reducedInput\images\maksssksksss10.png
# D:\DataScience\FaceMaskDetection\reducedInput\images\maksssksksss2.png
# D:\DataScience\FaceMaskDetection\reducedInput\images\maksssksksss3.png
# D:\DataScience\FaceMaskDetection\reducedInput\images\maksssksksss4.png
# D:\DataScience\FaceMaskDetection\reducedInput\images\maksssksksss5.png
# D:\DataScience\FaceMaskDetection\reducedInput\images\maksssksksss6.png
# D:\DataScience\FaceMaskDetection\reducedInput\images\maksssksksss7.png
# D:\DataScience\FaceMaskDetection\reducedInput\images\maksssksksss8.png
# D:\DataScience\FaceMaskDetection\reducedInput\images\maksssksksss9.png

# %%
# Path
img_dir = 'D:\\DataScience\\FaceMaskDetection\\reducedInput\\images'
annotation_dir = 'D:\\DataScience\\FaceMaskDetection\\reducedInput\\annotations'

input_dir = 'D:\\DataScience\\FaceMaskDetection\\reducedInput'
output_dir = 'D:\\DataScience\\FaceMaskDetection\\reducedOutput'

# %%
# sample visuaization
for idx, image in enumerate(os.listdir(img_dir)):
    img = cv2.imread(os.path.join(img_dir, image), 1)
    plt.imshow(img)
    plt.show()
    
    if idx == 3:
        break

# %%
# make img_file_path
img_file_path = []
for img in os.listdir(img_dir):
    image  = cv2.imread(os.path.join(img_dir, img), 0)
    img_file_path.append(f'{img}')

# %%
df = { 'name': [],
        'label': [],
      'width': [],
      'height': [],
     'xmin': [],
     'ymin': [],
     'xmax': [],
     'ymax': []}

for idx, anno in enumerate(glob.glob(annotation_dir + '/*.xml')):
    trees = ET.parse(anno)
    
    #print(anno)
    root = trees.getroot()
    width, height = [], []
    for item in root.iter():
        #print(item)
               
        if item.tag == 'size':
            for attr in list(item):
                if attr.tag == 'width':
                    width = int(round(float(attr.text)))
                if attr.tag == 'height':
                    height = int(round(float(attr.text)))
                    
        if item.tag == 'object':
            for attr in list(item):
                if 'name' in attr.tag:
                    label = attr.text
                    df['label'] += [label]
                    df['width'] += [width]
                    df['height'] += [height]
                    #dataset['name']+=[anno.split('/')[-1][0:-4]] 
                    df['name'] += [anno.split('\\')[-1][0:-4]]
                    
                if 'bndbox' in attr.tag:
                    for dim in attr:
                        if dim.tag == 'xmin':
                            xmin = int(round(float(dim.text)))
                            df['xmin'] += [xmin]
                            
                        if dim.tag == 'ymin':
                            ymin = int(round(float(dim.text)))
                            df['ymin'] += [ymin]
                        if dim.tag == 'xmax':
                            xmax = int(round(float(dim.text)))
                            df['xmax'] += [xmax]
                        if dim.tag == 'ymax':
                            ymax = int(round(float(dim.text)))
                            df['ymax'] += [ymax]

# %%
df1 = pd.DataFrame(df)
df1.head()
# Out:
#             name         label  width  height  xmin  ymin  xmax  ymax
# 0  maksssksksss0  without_mask    512     366    79   105   109   142
# 1  maksssksksss0     with_mask    512     366   185   100   226   144
# 2  maksssksksss0  without_mask    512     366   325    90   360   141
# 3  maksssksksss1     with_mask    400     156   321    34   354    69
# 4  maksssksksss1     with_mask    400     156   224    38   261    73

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    39 non-null     object
#  1   label   39 non-null     object
#  2   width   39 non-null     int64
#  3   height  39 non-null     int64
#  4   xmin    39 non-null     int64
#  5   ymin    39 non-null     int64
#  6   xmax    39 non-null     int64
#  7   ymax    39 non-null     int64
# dtypes: int64(6), object(2)
# memory usage: 2.6+ KB

# %%
label_map = { 'without_mask': 0,
            'with_mask': 1,
            'mask_weared_incorrect': 2}

df1['class'] = df1['label'].map(label_map)

# %%
# split train, test, val data
from sklearn.model_selection import train_test_split

train, test = train_test_split(img_file_path, test_size=0.2, random_state=101)
train, val = train_test_split(train, test_size=0.15, random_state=101)

# %%
# yolo v5
# %cd reducedOutput
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# !pip install -qr requirements.txt
# Out:
# D:\DataScience\FaceMaskDetection\reducedOutput
# D:\DataScience\FaceMaskDetection\reducedOutput\yolov5
# Cloning into 'yolov5'...
# WARNING: Ignoring invalid distribution -upyter-core (d:\softwares\python\lib\site-packages)
# WARNING: Ignoring invalid distribution -upyter-core (d:\softwares\python\lib\site-packages)

# %%
# create a separate folder structure for train, validation and test image and validation files
os.chdir(r'D:\\DataScience\\FaceMaskDetection\\reducedOutput')
os.mkdir(r'.\\yolov5\\data\\train')
os.mkdir(r'.\\yolov5\\data\\val')
os.mkdir(r'.\\yolov5\\data\\test')
os.mkdir(r'.\\yolov5\\data\\train\\images')
os.mkdir(r'.\\yolov5\\data\\train\\labels')
os.mkdir(r'.\\yolov5\\data\\val\\images')
os.mkdir(r'.\\yolov5\\data\\val\\labels')
os.mkdir(r'.\\yolov5\\data\\test\\images')
os.mkdir(r'.\\yolov5\\data\\test\\labels')

# %%
# copy the image data in the yolov5 folder 
def copy_image_file(image_items, folder_name):
    
    for image in image_items:
        img = PIL.Image.open(f'{img_dir}\\{image}')
        img1 = img.resize((640, 480))
        _ = img1.save(f'{output_dir}\\yolov5\\data\\{folder_name}\\images\\{image}')

copy_image_file(train, 'train')
copy_image_file(val, 'val')
copy_image_file(test, 'test')

# %%
df1['xmin'] = (640/df1['width']) * df1['xmin']
df1['ymin'] = (480/df1['height']) * df1['ymin']
df1['xmax'] = (640/df1['width']) * df1['xmax']
df1['ymax'] = (480/df1['height']) * df1['ymax']
df1.head()
# Out:
#             name         label  width  height    xmin        ymin    xmax  \
# 0  maksssksksss0  without_mask    512     366   98.75  137.704918  136.25
# 1  maksssksksss0     with_mask    512     366  231.25  131.147541  282.50
# 2  maksssksksss0  without_mask    512     366  406.25  118.032787  450.00
# 3  maksssksksss1     with_mask    400     156  513.60  104.615385  566.40
# 4  maksssksksss1     with_mask    400     156  358.40  116.923077  417.60
#
#          ymax  class
# 0  186.229508      0
# 1  188.852459      1
# 2  184.918033      0
# 3  212.307692      1
# 4  224.615385      1

# %%
df1[['xmin', 'ymin', 'xmax', 'ymax']] = df1[['xmin', 'ymin', 'xmax', 'ymax']].astype('int')

# %%
WIDTH = 640
HEIGHT = 480

# %%
df1['x_center'] = (df1['xmin']+df1['xmax'])/(2*WIDTH)
df1['y_center'] = (df1['ymin']+df1['ymax'])/(2*HEIGHT)
df1['box_width'] = (df1['xmax']-df1['xmin'])/ WIDTH
df1['box_height'] = (df1['ymax']-df1['ymin'])/ HEIGHT

# %%
df1.head()
# Out:
#             name         label  width  height  xmin  ymin  xmax  ymax  class  \
# 0  maksssksksss0  without_mask    512     366    98   137   136   186      0
# 1  maksssksksss0     with_mask    512     366   231   131   282   188      1
# 2  maksssksksss0  without_mask    512     366   406   118   450   184      0
# 3  maksssksksss1     with_mask    400     156   513   104   566   212      1
# 4  maksssksksss1     with_mask    400     156   358   116   417   224      1
#
#    x_center  y_center  box_width  box_height
# 0  0.182812  0.336458   0.059375    0.102083
# 1  0.400781  0.332292   0.079687    0.118750
# 2  0.668750  0.314583   0.068750    0.137500
# 3  0.842969  0.329167   0.082812    0.225000
# 4  0.605469  0.354167   0.092188    0.225000

# %%
df1 = df1.astype(str)

# %%
img_file_path[:5]
# Out:
# ['maksssksksss0.png',
#  'maksssksksss1.png',
#  'maksssksksss10.png',
#  'maksssksksss2.png',
#  'maksssksksss3.png']

# %%
# copy the label data in the yolov5 folder 

def copy_label(label_items, folder_name):
    file_name = [x.split('.')[0] for x in img_file_path]
    for name in file_name:
        data = df1[df1.name == name]

        box_list = []
        for idx in range(len(data)):
            row = data.iloc[idx]
            box_list.append(row['class']+" "+row['x_center']+" "+row['y_center']+" "+ row['box_width']+" "+row['box_height'])

        text = "\n".join(box_list)
        with open(f'{output_dir}\\yolov5\\data\\{folder_name}\\labels\\{name}.txt', 'w') as file:
            file.write(text)

# %%
copy_label(train, 'train')
copy_label(val, 'val')
copy_label(test, 'test')

# %%
os.chdir(f'D:\\DataScience\\FaceMaskDetection\\reducedOutput\\yolov5\\data\\train\\labels')

# %%
# Configure .yaml file 
yaml_file = """train: D:\\DataScience\\FaceMaskDetection\\reducedOutput\\yolov5\\data\\train\\images
val: D:\\DataScience\\FaceMaskDetection\\reducedOutput\\yolov5\\data\\val\\images
                
nc: 3

names: [without_mask, with_mask, mask_weared_incorrect]"""

with open('D:\\DataScience\\FaceMaskDetection\\reducedOutput\\yolov5\\data\\data.yaml', 'w') as f:
    f.write(yaml_file)

# %% [markdown]
# ## Model Training

# %%
# !python D:/DataScience/FaceMaskDetection/reducedOutput/yolov5/train.py --img 640 --epochs 50 --batch 32 --data D:/DataScience/FaceMaskDetection/reducedOutput/yolov5/data/data.yaml --cfg D:/DataScience/FaceMaskDetection/reducedOutput/yolov5/models/yolov5s.yaml --weights yolov5s.pt --name mask_wearing_yolov5
